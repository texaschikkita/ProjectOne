# %% [markdown]
# We are assisting the music industry to pinpoint the exact features to create top streaming music. These findings will help determine any trends that help produce a top streaming music/songs.
#
# Question 1: What features have been most prevalent in the past 10 years for a top streaming music/song?

# %%
# import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as st
from scipy.stats import linregress

# %%
#read in csv files

songs_w_features_df = pd.read_csv("data.csv")

# %%
# data clean songs data frame to reduce columns

songs_w_features_df_reduced = songs_w_features_df[["acousticness", "artists", "danceability", "energy", "liveness",
                                                    "loudness", "name", "popularity", "tempo", "year" ]]

songs_w_features_df_reduced
# Out:
#         acousticness                                   artists  danceability  \
# 0             0.9950                       ['Carl Woitschach']         0.708
# 1             0.9940  ['Robert Schumann', 'Vladimir Horowitz']         0.379
# 2             0.6040                   ['Seweryn Goszczyński']         0.749
# 3             0.9950                      ['Francisco Canaro']         0.781
# 4             0.9900  ['Frédéric Chopin', 'Vladimir Horowitz']         0.210
# ...              ...                                       ...           ...
# 169904        0.1730                    ['DripReport', 'Tyga']         0.875
# 169905        0.0167        ['Leon Bridges', 'Terrace Martin']         0.719
# 169906        0.5380                     ['Kygo', 'Oh Wonder']         0.514
# 169907        0.0714             ['Cash Cash', 'Andy Grammer']         0.646
# 169908        0.1090                        ['Ingrid Andress']         0.512
#
#         energy  liveness  loudness  \
# 0       0.1950    0.1510   -12.428
# 1       0.0135    0.0763   -28.454
# 2       0.2200    0.1190   -19.924
# 3       0.1300    0.1110   -14.734
# 4       0.2040    0.0980   -16.829
# ...        ...       ...       ...
# 169904  0.4430    0.0891    -7.461
# 169905  0.3850    0.1110   -10.907
# 169906  0.5390    0.1080    -9.332
# 169907  0.7610    0.2220    -2.557
# 169908  0.4280    0.1050    -7.387
#
#                                                  name  popularity    tempo  \
# 0                         Singende Bataillone 1. Teil           0  118.469
# 1            Fantasiestücke, Op. 111: Più tosto lento           0   83.972
# 2                      Chapter 1.18 - Zamek kaniowski           0  107.177
# 3       Bebamos Juntos - Instrumental (Remasterizado)           0  108.003
# 4         Polonaise-Fantaisie in A-Flat Major, Op. 61           1   62.149
# ...                                               ...         ...      ...
# 169904                  Skechers (feat. Tyga) - Remix          75  100.012
# 169905                 Sweeter (feat. Terrace Martin)          64  128.000
# 169906                               How Would I Know          70  123.700
# 169907                                    I Found You          70  129.916
# 169908                          More Hearts Than Mine          65   80.588
#
#         year
# 0       1928
# 1       1928
# 2       1928
# 3       1928
# 4       1928
# ...      ...
# 169904  2020
# 169905  2020
# 169906  2020
# 169907  2020
# 169908  2020
#
# [169909 rows x 10 columns]

# %%
# filter df to show songs after 2010

filter_songs_w_features = songs_w_features_df_reduced[songs_w_features_df_reduced["year"] >= 2010]

filter_songs_w_features
# Out:
#         acousticness                             artists  danceability  \
# 7054        0.022200                     ['Tame Impala']         0.450
# 7055        0.000103            ['Bring Me The Horizon']         0.382
# 7056        0.852000                       ['Daft Punk']         0.179
# 7057        0.080900                         ['TobyMac']         0.507
# 7058        0.002960                   ['Kenny Chesney']         0.315
# ...              ...                                 ...           ...
# 169904      0.173000              ['DripReport', 'Tyga']         0.875
# 169905      0.016700  ['Leon Bridges', 'Terrace Martin']         0.719
# 169906      0.538000               ['Kygo', 'Oh Wonder']         0.514
# 169907      0.071400       ['Cash Cash', 'Andy Grammer']         0.646
# 169908      0.109000                  ['Ingrid Andress']         0.512
#
#         energy  liveness  loudness                            name  \
# 7054     0.849    0.0792    -5.075                     Expectation
# 7055     0.943    0.3960    -5.434                   It Never Ends
# 7056     0.167    0.1060   -23.408                    Solar Sailer
# 7057     0.770    0.2140    -5.018               City On Our Knees
# 7058     0.925    0.1140    -4.507                         Reality
# ...        ...       ...       ...                             ...
# 169904   0.443    0.0891    -7.461   Skechers (feat. Tyga) - Remix
# 169905   0.385    0.1110   -10.907  Sweeter (feat. Terrace Martin)
# 169906   0.539    0.1080    -9.332                How Would I Know
# 169907   0.761    0.2220    -2.557                     I Found You
# 169908   0.428    0.1050    -7.387           More Hearts Than Mine
#
#         popularity    tempo  year
# 7054            48  139.925  2010
# 7055            50  105.032  2010
# 7056            48  124.266  2010
# 7057            48  155.945  2010
# 7058            47  185.305  2010
# ...            ...      ...   ...
# 169904          75  100.012  2020
# 169905          64  128.000  2020
# 169906          70  123.700  2020
# 169907          70  129.916  2020
# 169908          65   80.588  2020
#
# [21656 rows x 10 columns]

# %%
#reset index

new_index_features = filter_songs_w_features.reset_index(drop=True)

# %%
#sort by popularity

sorted_df = new_index_features.sort_values("popularity")

sorted_df
# Out:
#        acousticness                                     artists  danceability  \
# 15076       0.13500                  ['A Boogie Wit da Hoodie']         0.698
# 3262        0.35700                            ['Jack Johnson']         0.856
# 5472        0.03700               ['Luis Fonsi', 'Demi Lovato']         0.713
# 9690        0.01090               ['Jax Jones', 'Ina Wroldsen']         0.695
# 2183        0.65100          ['Arijit Singh', 'Shreya Ghoshal']         0.614
# ...             ...                                         ...           ...
# 11760       0.30500                  ['BENEE', 'Gus Dapperton']         0.863
# 11857       0.23300  ['THE SCOTTS', 'Travis Scott', 'Kid Cudi']         0.716
# 11865       0.73100                    ['Powfu', 'beabadoobee']         0.726
# 11856       0.24700                   ['DaBaby', 'Roddy Ricch']         0.746
# 11858       0.00146                              ['The Weeknd']         0.514
#
#        energy  liveness  loudness  \
# 15076   0.572    0.1540    -7.735
# 3262    0.418    0.1110    -7.375
# 5472    0.916    0.0681    -3.310
# 9690    0.820    0.0605    -4.985
# 2183    0.711    0.0862    -8.425
# ...       ...       ...       ...
# 11760   0.631    0.1230    -4.689
# 11857   0.537    0.1570    -7.648
# 11865   0.431    0.6960    -8.765
# 11856   0.690    0.1010    -7.956
# 11858   0.730    0.0897    -5.934
#
#                                                     name  popularity    tempo  \
# 15076                                              Bleed           0   71.446
# 3262                                     Better Together           0  110.093
# 5472                                     Échame La Culpa           0   95.996
# 9690                                             Breathe           0  125.881
# 2183                                 Balir Shohor Female           0  107.961
# ...                                                  ...         ...      ...
# 11760                                         Supalonely          95  128.977
# 11857                                         THE SCOTTS          96  129.979
# 11865  death bed (coffee for your head) (feat. beabad...          97  144.026
# 11856                       ROCKSTAR (feat. Roddy Ricch)          99   89.977
# 11858                                    Blinding Lights         100  171.005
#
#        year
# 15076  2020
# 3262   2020
# 5472   2020
# 9690   2020
# 2183   2020
# ...     ...
# 11760  2019
# 11857  2020
# 11865  2020
# 11856  2020
# 11858  2020
#
# [21656 rows x 10 columns]

# %%
#get all the years from the last 10 years

print(sorted_df['year'].unique())
# Out:
# [2020 2010 2011 2012 2013 2014 2015 2016 2017 2018 2019]

# %%
#see all features
print(sorted_df.columns)
# Out:
# Index(['acousticness', 'artists', 'danceability', 'energy', 'liveness',
#        'loudness', 'name', 'popularity', 'tempo', 'year'],
#       dtype='object')

# %%
#group by year, top 5 per year


top_songs = sorted_df.groupby('year').apply(lambda x: x.sort_values(['popularity'], ascending=False).head(5))
top_songs = top_songs.drop('year', axis=1)
top_songs
# Out:
#             acousticness                                            artists  \
# year
# 2010 10856       0.18500                                          ['Train']
#      10862       0.24100                              ['Eminem', 'Rihanna']
#      10861       0.09910                                          ['Kesha']
#      10857       0.01510                                     ['Bruno Mars']
#      10864       0.01620                                     ['Kanye West']
# 2011 10957       0.14500                              ['Foster The People']
#      10956       0.00847                                      ['Grouplove']
#      10978       0.19200          ['Pitbull', 'Ne-Yo', 'Afrojack', 'Nayer']
#      10958       0.05310                                        ['J. Cole']
#      10965       0.30900                                ['Christina Perri']
# 2012 11060       0.02910                        ['Macklemore & Ryan Lewis']
#      11057       0.93200                                     ['Bruno Mars']
#      11073       0.34600                             ['P!nk', 'Nate Ruess']
#      11070       0.04900                                     ['Bruno Mars']
#      11077       0.00900                                  ['One Direction']
# 2013 11159       0.92200                                    ['John Legend']
#      11162       0.00380                                         ['Avicii']
#      11165       0.18600                                 ['Arctic Monkeys']
#      11168       0.22500                                  ['One Direction']
#      11158       0.04950                              ['The Neighbourhood']
# 2014 11284       0.60700                                     ['Ed Sheeran']
#      11276       0.47400                                     ['Ed Sheeran']
#      11272       0.52900                                      ['Sam Smith']
#      11311       0.10100                  ['Aaron Smith', 'Krono', 'Luvli']
#      11261       0.58800                                      ['Sam Smith']
# 2015 11356       0.61200                               ['Melanie Martinez']
#      11357       0.01150                                    ['Tame Impala']
#      11367       0.04620                              ['Twenty One Pilots']
#      11358       0.03710                                         ['WILLOW']
#      11381       0.36900                    ['Wiz Khalifa', 'Charlie Puth']
# 2016 11456       0.08470                                   ['Travis Scott']
#      11462       0.41400                     ['The Chainsmokers', 'Halsey']
#      11460       0.69500                                   ['James Arthur']
#      11463       0.14100                        ['The Weeknd', 'Daft Punk']
#      11457       0.06890                                    ['Post Malone']
# 2017 11576       0.06220                                ['Imagine Dragons']
#      11556       0.46900                                   ['XXXTENTACION']
#      11580       0.16300                                     ['Ed Sheeran']
#      11569       0.79100  ['Erik Eriksson', 'White Noise Baby Sleep', 'W...
#      11615       0.58100                                     ['Ed Sheeran']
# 2018 11658       0.00513                                   ['Travis Scott']
#      11657       0.12300                                  ['Trevor Daniel']
#      11656       0.34900                                     ['Juice WRLD']
#      11663       0.93400                        ['Billie Eilish', 'Khalid']
#      11664       0.25800                                   ['XXXTENTACION']
# 2019 11760       0.30500                         ['BENEE', 'Gus Dapperton']
#      11756       0.10400                                    ['Roddy Ricch']
#      11768       0.06860                            ['Surf Mesa', 'Emilee']
#      11774       0.69200                                    ['Tones And I']
#      11761       0.25600                                       ['Doja Cat']
# 2020 11858       0.00146                                     ['The Weeknd']
#      11856       0.24700                          ['DaBaby', 'Roddy Ricch']
#      11865       0.73100                           ['Powfu', 'beabadoobee']
#      11857       0.23300         ['THE SCOTTS', 'Travis Scott', 'Kid Cudi']
#      11862       0.32100                                          ['Drake']
#
#             danceability   energy  liveness  loudness  \
# year
# 2010 10856         0.673  0.88600    0.0826    -4.440
#      10862         0.749  0.92500    0.5200    -5.034
#      10861         0.755  0.83700    0.2890    -2.718
#      10857         0.637  0.84300    0.0876    -5.413
#      10864         0.543  0.91500    0.7440    -4.746
# 2011 10957         0.733  0.71000    0.0956    -5.849
#      10956         0.560  0.93600    0.1610    -5.835
#      10978         0.671  0.93900    0.2980    -3.206
#      10958         0.831  0.42700    0.3070    -6.903
#      10965         0.421  0.40700    0.1100    -7.445
# 2012 11060         0.641  0.92200    0.0862    -4.457
#      11057         0.612  0.28000    0.0880    -8.648
#      11073         0.778  0.54700    0.1320    -7.273
#      11070         0.726  0.69800    0.3090    -4.165
#      11077         0.726  0.78700    0.0596    -2.494
# 2013 11159         0.422  0.26400    0.1320    -7.064
#      11162         0.532  0.78300    0.1610    -5.697
#      11165         0.548  0.53200    0.2170    -7.596
#      11168         0.600  0.66300    0.1190    -5.802
#      11158         0.612  0.80700    0.1010    -2.810
# 2014 11284         0.614  0.37900    0.0986   -10.480
#      11276         0.781  0.44500    0.1840    -6.061
#      11272         0.677  0.48500    0.0766    -5.795
#      11311         0.720  0.74100    0.2890    -6.529
#      11261         0.418  0.42000    0.1100    -6.444
# 2015 11356         0.680  0.72900    0.2240    -5.077
#      11357         0.640  0.74000    0.1670    -4.083
#      11367         0.734  0.63700    0.0602    -5.677
#      11358         0.764  0.70500    0.0943    -5.279
#      11381         0.689  0.48100    0.0649    -7.503
# 2016 11456         0.841  0.72800    0.1490    -3.370
#      11462         0.748  0.52400    0.1110    -5.599
#      11460         0.358  0.55700    0.0902    -7.398
#      11463         0.679  0.58700    0.1370    -7.015
#      11457         0.556  0.53800    0.1960    -5.408
# 2017 11576         0.776  0.78000    0.0810    -4.374
#      11556         0.872  0.39100    0.2970    -9.144
#      11580         0.599  0.44800    0.1060    -6.312
#      11569         0.000  0.00342    0.1110   -28.460
#      11615         0.825  0.65200    0.0931    -3.183
# 2018 11658         0.834  0.73000    0.1240    -3.714
#      11657         0.784  0.43000    0.0887    -8.756
#      11656         0.511  0.56600    0.3400    -7.230
#      11663         0.351  0.29600    0.0950   -10.109
#      11664         0.740  0.61300    0.1230    -4.880
# 2019 11760         0.863  0.63100    0.1230    -4.689
#      11756         0.896  0.58600    0.7900    -6.687
#      11768         0.674  0.77400    0.3930    -7.567
#      11774         0.824  0.58800    0.1490    -6.400
#      11761         0.787  0.67300    0.0904    -4.577
# 2020 11858         0.514  0.73000    0.0897    -5.934
#      11856         0.746  0.69000    0.1010    -7.956
#      11865         0.726  0.43100    0.6960    -8.765
#      11857         0.716  0.53700    0.1570    -7.648
#      11862         0.834  0.45400    0.1140    -9.750
#
#                                                          name  popularity  \
# year
# 2010 10856                                   Hey, Soul Sister          82
#      10862                               Love The Way You Lie          81
#      10861                                            TiK ToK          80
#      10857                               Just the Way You Are          80
#      10864                                              POWER          78
# 2011 10957                                    Pumped Up Kicks          83
#      10956                                        Tongue Tied          81
#      10978  Give Me Everything (feat. Ne-Yo, Afrojack & Na...          79
#      10958                                           Work Out          79
#      10965                                   A Thousand Years          79
# 2012 11060                   Can't Hold Us - feat. Ray Dalton          82
#      11057                                When I Was Your Man          82
#      11073           Just Give Me a Reason (feat. Nate Ruess)          80
#      11070                               Locked out of Heaven          80
#      11077                           What Makes You Beautiful          80
# 2013 11159                                          All of Me          85
#      11162                                         Wake Me Up          84
#      11165                                   Do I Wanna Know?          82
#      11168                                   Story of My Life          81
#      11158                                    Sweater Weather          81
# 2014 11284                                         Photograph          83
#      11276                                  Thinking out Loud          82
#      11272                               I'm Not The Only One          82
#      11311                 Dancin (feat. Luvli) - Krono Remix          82
#      11261                                       Stay With Me          82
# 2015 11356                                          Play Date          91
#      11357                         The Less I Know The Better          85
#      11367                                       Stressed Out          83
#      11358                                     Wait a Minute!          83
#      11381                 See You Again (feat. Charlie Puth)          82
# 2016 11456                                         goosebumps          92
#      11462                                             Closer          84
#      11460                               Say You Won't Let Go          84
#      11463                                            Starboy          84
#      11457                                       I Fall Apart          83
# 2017 11576                                           Believer          87
#      11556                                     Jocelyn Flores          87
#      11580                                            Perfect          86
#      11569          Clean White Noise - Loopable with no fade          86
#      11615                                       Shape of You          85
# 2018 11658                                         SICKO MODE          92
#      11657                                            Falling          92
#      11656                                       Lucid Dreams          89
#      11663                               lovely (with Khalid)          89
#      11664                                               SAD!          87
# 2019 11760                                         Supalonely          95
#      11756                                            The Box          95
#      11768               ily (i love you baby) (feat. Emilee)          95
#      11774                                       Dance Monkey          94
#      11761                                             Say So          93
# 2020 11858                                    Blinding Lights         100
#      11856                       ROCKSTAR (feat. Roddy Ricch)          99
#      11865  death bed (coffee for your head) (feat. beabad...          97
#      11857                                         THE SCOTTS          96
#      11862                                       Toosie Slide          95
#
#               tempo
# year
# 2010 10856   97.012
#      10862   86.989
#      10861  120.028
#      10857  109.012
#      10864  153.998
# 2011 10957  127.975
#      10956  112.960
#      10978  129.023
#      10958   93.004
#      10965  139.028
# 2012 11060  146.078
#      11057   72.795
#      11073   95.002
#      11070  143.994
#      11077  124.990
# 2013 11159  119.930
#      11162  124.080
#      11165   85.030
#      11168  121.070
#      11158  124.053
# 2014 11284  107.989
#      11276   78.998
#      11272   82.001
#      11311  119.896
#      11261   84.094
# 2015 11356  123.970
#      11357  116.879
#      11367  169.977
#      11358  101.003
#      11381   80.025
# 2016 11456  130.049
#      11462   95.010
#      11460   85.043
#      11463  186.003
#      11457  143.950
# 2017 11576  124.949
#      11556  134.021
#      11580   95.050
#      11569    0.000
#      11615   95.977
# 2018 11658  155.008
#      11657  127.087
#      11656   83.903
#      11663  115.284
#      11664   75.023
# 2019 11760  128.977
#      11756  116.971
#      11768  112.050
#      11774   98.027
#      11761  110.962
# 2020 11858  171.005
#      11856   89.977
#      11865  144.026
#      11857  129.979
#      11862   81.618

# %%
top_songs.describe()
# Out:
#        acousticness  danceability     energy   liveness   loudness  \
# count     55.000000     55.000000  55.000000  55.000000  55.000000
# mean       0.281603      0.664382   0.614680   0.187515  -6.462691
# std        0.270509      0.160450   0.196764   0.164359   3.566008
# min        0.001460      0.000000   0.003420   0.059600 -28.460000
# 25%        0.057650      0.599500   0.467500   0.093700  -7.421500
# 50%        0.192000      0.689000   0.631000   0.123000  -5.849000
# 75%        0.441500      0.770000   0.740500   0.206500  -4.717500
# max        0.934000      0.896000   0.939000   0.790000  -2.494000
#
#        popularity       tempo
# count   55.000000   55.000000
# mean    85.818182  113.106036
# std      5.891271   30.334678
# min     78.000000    0.000000
# 25%     82.000000   94.003000
# 50%     84.000000  116.879000
# 75%     90.000000  129.000000
# max    100.000000  186.003000

# %%
# Calculate summary statistics per year, for top 5 songs
grouped = top_songs.groupby('name')[['acousticness', 'danceability', 'energy','liveness', 'loudness','tempo']].agg(['mean', 'median', 'std', 'min', 'max'])

grouped
# Out:
#                                                    acousticness               \
#                                                            mean   median std
# name
# A Thousand Years                                        0.30900  0.30900 NaN
# All of Me                                               0.92200  0.92200 NaN
# Believer                                                0.06220  0.06220 NaN
# Blinding Lights                                         0.00146  0.00146 NaN
# Can't Hold Us - feat. Ray Dalton                        0.02910  0.02910 NaN
# Clean White Noise - Loopable with no fade               0.79100  0.79100 NaN
# Closer                                                  0.41400  0.41400 NaN
# Dance Monkey                                            0.69200  0.69200 NaN
# Dancin (feat. Luvli) - Krono Remix                      0.10100  0.10100 NaN
# Do I Wanna Know?                                        0.18600  0.18600 NaN
# Falling                                                 0.12300  0.12300 NaN
# Give Me Everything (feat. Ne-Yo, Afrojack & Nayer)      0.19200  0.19200 NaN
# Hey, Soul Sister                                        0.18500  0.18500 NaN
# I Fall Apart                                            0.06890  0.06890 NaN
# I'm Not The Only One                                    0.52900  0.52900 NaN
# Jocelyn Flores                                          0.46900  0.46900 NaN
# Just Give Me a Reason (feat. Nate Ruess)                0.34600  0.34600 NaN
# Just the Way You Are                                    0.01510  0.01510 NaN
# Locked out of Heaven                                    0.04900  0.04900 NaN
# Love The Way You Lie                                    0.24100  0.24100 NaN
# Lucid Dreams                                            0.34900  0.34900 NaN
# POWER                                                   0.01620  0.01620 NaN
# Perfect                                                 0.16300  0.16300 NaN
# Photograph                                              0.60700  0.60700 NaN
# Play Date                                               0.61200  0.61200 NaN
# Pumped Up Kicks                                         0.14500  0.14500 NaN
# ROCKSTAR (feat. Roddy Ricch)                            0.24700  0.24700 NaN
# SAD!                                                    0.25800  0.25800 NaN
# SICKO MODE                                              0.00513  0.00513 NaN
# Say So                                                  0.25600  0.25600 NaN
# Say You Won't Let Go                                    0.69500  0.69500 NaN
# See You Again (feat. Charlie Puth)                      0.36900  0.36900 NaN
# Shape of You                                            0.58100  0.58100 NaN
# Starboy                                                 0.14100  0.14100 NaN
# Stay With Me                                            0.58800  0.58800 NaN
# Story of My Life                                        0.22500  0.22500 NaN
# Stressed Out                                            0.04620  0.04620 NaN
# Supalonely                                              0.30500  0.30500 NaN
# Sweater Weather                                         0.04950  0.04950 NaN
# THE SCOTTS                                              0.23300  0.23300 NaN
# The Box                                                 0.10400  0.10400 NaN
# The Less I Know The Better                              0.01150  0.01150 NaN
# Thinking out Loud                                       0.47400  0.47400 NaN
# TiK ToK                                                 0.09910  0.09910 NaN
# Tongue Tied                                             0.00847  0.00847 NaN
# Toosie Slide                                            0.32100  0.32100 NaN
# Wait a Minute!                                          0.03710  0.03710 NaN
# Wake Me Up                                              0.00380  0.00380 NaN
# What Makes You Beautiful                                0.00900  0.00900 NaN
# When I Was Your Man                                     0.93200  0.93200 NaN
# Work Out                                                0.05310  0.05310 NaN
# death bed (coffee for your head) (feat. beabado...      0.73100  0.73100 NaN
# goosebumps                                              0.08470  0.08470 NaN
# ily (i love you baby) (feat. Emilee)                    0.06860  0.06860 NaN
# lovely (with Khalid)                                    0.93400  0.93400 NaN
#
#                                                                       \
#                                                         min      max
# name
# A Thousand Years                                    0.30900  0.30900
# All of Me                                           0.92200  0.92200
# Believer                                            0.06220  0.06220
# Blinding Lights                                     0.00146  0.00146
# Can't Hold Us - feat. Ray Dalton                    0.02910  0.02910
# Clean White Noise - Loopable with no fade           0.79100  0.79100
# Closer                                              0.41400  0.41400
# Dance Monkey                                        0.69200  0.69200
# Dancin (feat. Luvli) - Krono Remix                  0.10100  0.10100
# Do I Wanna Know?                                    0.18600  0.18600
# Falling                                             0.12300  0.12300
# Give Me Everything (feat. Ne-Yo, Afrojack & Nayer)  0.19200  0.19200
# Hey, Soul Sister                                    0.18500  0.18500
# I Fall Apart                                        0.06890  0.06890
# I'm Not The Only One                                0.52900  0.52900
# Jocelyn Flores                                      0.46900  0.46900
# Just Give Me a Reason (feat. Nate Ruess)            0.34600  0.34600
# Just the Way You Are                                0.01510  0.01510
# Locked out of Heaven                                0.04900  0.04900
# Love The Way You Lie                                0.24100  0.24100
# Lucid Dreams                                        0.34900  0.34900
# POWER                                               0.01620  0.01620
# Perfect                                             0.16300  0.16300
# Photograph                                          0.60700  0.60700
# Play Date                                           0.61200  0.61200
# Pumped Up Kicks                                     0.14500  0.14500
# ROCKSTAR (feat. Roddy Ricch)                        0.24700  0.24700
# SAD!                                                0.25800  0.25800
# SICKO MODE                                          0.00513  0.00513
# Say So                                              0.25600  0.25600
# Say You Won't Let Go                                0.69500  0.69500
# See You Again (feat. Charlie Puth)                  0.36900  0.36900
# Shape of You                                        0.58100  0.58100
# Starboy                                             0.14100  0.14100
# Stay With Me                                        0.58800  0.58800
# Story of My Life                                    0.22500  0.22500
# Stressed Out                                        0.04620  0.04620
# Supalonely                                          0.30500  0.30500
# Sweater Weather                                     0.04950  0.04950
# THE SCOTTS                                          0.23300  0.23300
# The Box                                             0.10400  0.10400
# The Less I Know The Better                          0.01150  0.01150
# Thinking out Loud                                   0.47400  0.47400
# TiK ToK                                             0.09910  0.09910
# Tongue Tied                                         0.00847  0.00847
# Toosie Slide                                        0.32100  0.32100
# Wait a Minute!                                      0.03710  0.03710
# Wake Me Up                                          0.00380  0.00380
# What Makes You Beautiful                            0.00900  0.00900
# When I Was Your Man                                 0.93200  0.93200
# Work Out                                            0.05310  0.05310
# death bed (coffee for your head) (feat. beabado...  0.73100  0.73100
# goosebumps                                          0.08470  0.08470
# ily (i love you baby) (feat. Emilee)                0.06860  0.06860
# lovely (with Khalid)                                0.93400  0.93400
#
#                                                    danceability             \
#                                                            mean median std
# name
# A Thousand Years                                          0.421  0.421 NaN
# All of Me                                                 0.422  0.422 NaN
# Believer                                                  0.776  0.776 NaN
# Blinding Lights                                           0.514  0.514 NaN
# Can't Hold Us - feat. Ray Dalton                          0.641  0.641 NaN
# Clean White Noise - Loopable with no fade                 0.000  0.000 NaN
# Closer                                                    0.748  0.748 NaN
# Dance Monkey                                              0.824  0.824 NaN
# Dancin (feat. Luvli) - Krono Remix                        0.720  0.720 NaN
# Do I Wanna Know?                                          0.548  0.548 NaN
# Falling                                                   0.784  0.784 NaN
# Give Me Everything (feat. Ne-Yo, Afrojack & Nayer)        0.671  0.671 NaN
# Hey, Soul Sister                                          0.673  0.673 NaN
# I Fall Apart                                              0.556  0.556 NaN
# I'm Not The Only One                                      0.677  0.677 NaN
# Jocelyn Flores                                            0.872  0.872 NaN
# Just Give Me a Reason (feat. Nate Ruess)                  0.778  0.778 NaN
# Just the Way You Are                                      0.637  0.637 NaN
# Locked out of Heaven                                      0.726  0.726 NaN
# Love The Way You Lie                                      0.749  0.749 NaN
# Lucid Dreams                                              0.511  0.511 NaN
# POWER                                                     0.543  0.543 NaN
# Perfect                                                   0.599  0.599 NaN
# Photograph                                                0.614  0.614 NaN
# Play Date                                                 0.680  0.680 NaN
# Pumped Up Kicks                                           0.733  0.733 NaN
# ROCKSTAR (feat. Roddy Ricch)                              0.746  0.746 NaN
# SAD!                                                      0.740  0.740 NaN
# SICKO MODE                                                0.834  0.834 NaN
# Say So                                                    0.787  0.787 NaN
# Say You Won't Let Go                                      0.358  0.358 NaN
# See You Again (feat. Charlie Puth)                        0.689  0.689 NaN
# Shape of You                                              0.825  0.825 NaN
# Starboy                                                   0.679  0.679 NaN
# Stay With Me                                              0.418  0.418 NaN
# Story of My Life                                          0.600  0.600 NaN
# Stressed Out                                              0.734  0.734 NaN
# Supalonely                                                0.863  0.863 NaN
# Sweater Weather                                           0.612  0.612 NaN
# THE SCOTTS                                                0.716  0.716 NaN
# The Box                                                   0.896  0.896 NaN
# The Less I Know The Better                                0.640  0.640 NaN
# Thinking out Loud                                         0.781  0.781 NaN
# TiK ToK                                                   0.755  0.755 NaN
# Tongue Tied                                               0.560  0.560 NaN
# Toosie Slide                                              0.834  0.834 NaN
# Wait a Minute!                                            0.764  0.764 NaN
# Wake Me Up                                                0.532  0.532 NaN
# What Makes You Beautiful                                  0.726  0.726 NaN
# When I Was Your Man                                       0.612  0.612 NaN
# Work Out                                                  0.831  0.831 NaN
# death bed (coffee for your head) (feat. beabado...        0.726  0.726 NaN
# goosebumps                                                0.841  0.841 NaN
# ily (i love you baby) (feat. Emilee)                      0.674  0.674 NaN
# lovely (with Khalid)                                      0.351  0.351 NaN
#
#                                                                   ...  \
#                                                       min    max  ...
# name                                                              ...
# A Thousand Years                                    0.421  0.421  ...
# All of Me                                           0.422  0.422  ...
# Believer                                            0.776  0.776  ...
# Blinding Lights                                     0.514  0.514  ...
# Can't Hold Us - feat. Ray Dalton                    0.641  0.641  ...
# Clean White Noise - Loopable with no fade           0.000  0.000  ...
# Closer                                              0.748  0.748  ...
# Dance Monkey                                        0.824  0.824  ...
# Dancin (feat. Luvli) - Krono Remix                  0.720  0.720  ...
# Do I Wanna Know?                                    0.548  0.548  ...
# Falling                                             0.784  0.784  ...
# Give Me Everything (feat. Ne-Yo, Afrojack & Nayer)  0.671  0.671  ...
# Hey, Soul Sister                                    0.673  0.673  ...
# I Fall Apart                                        0.556  0.556  ...
# I'm Not The Only One                                0.677  0.677  ...
# Jocelyn Flores                                      0.872  0.872  ...
# Just Give Me a Reason (feat. Nate Ruess)            0.778  0.778  ...
# Just the Way You Are                                0.637  0.637  ...
# Locked out of Heaven                                0.726  0.726  ...
# Love The Way You Lie                                0.749  0.749  ...
# Lucid Dreams                                        0.511  0.511  ...
# POWER                                               0.543  0.543  ...
# Perfect                                             0.599  0.599  ...
# Photograph                                          0.614  0.614  ...
# Play Date                                           0.680  0.680  ...
# Pumped Up Kicks                                     0.733  0.733  ...
# ROCKSTAR (feat. Roddy Ricch)                        0.746  0.746  ...
# SAD!                                                0.740  0.740  ...
# SICKO MODE                                          0.834  0.834  ...
# Say So                                              0.787  0.787  ...
# Say You Won't Let Go                                0.358  0.358  ...
# See You Again (feat. Charlie Puth)                  0.689  0.689  ...
# Shape of You                                        0.825  0.825  ...
# Starboy                                             0.679  0.679  ...
# Stay With Me                                        0.418  0.418  ...
# Story of My Life                                    0.600  0.600  ...
# Stressed Out                                        0.734  0.734  ...
# Supalonely                                          0.863  0.863  ...
# Sweater Weather                                     0.612  0.612  ...
# THE SCOTTS                                          0.716  0.716  ...
# The Box                                             0.896  0.896  ...
# The Less I Know The Better                          0.640  0.640  ...
# Thinking out Loud                                   0.781  0.781  ...
# TiK ToK                                             0.755  0.755  ...
# Tongue Tied                                         0.560  0.560  ...
# Toosie Slide                                        0.834  0.834  ...
# Wait a Minute!                                      0.764  0.764  ...
# Wake Me Up                                          0.532  0.532  ...
# What Makes You Beautiful                            0.726  0.726  ...
# When I Was Your Man                                 0.612  0.612  ...
# Work Out                                            0.831  0.831  ...
# death bed (coffee for your head) (feat. beabado...  0.726  0.726  ...
# goosebumps                                          0.841  0.841  ...
# ily (i love you baby) (feat. Emilee)                0.674  0.674  ...
# lovely (with Khalid)                                0.351  0.351  ...
#
#                                                    loudness              \
#                                                        mean  median std
# name
# A Thousand Years                                     -7.445  -7.445 NaN
# All of Me                                            -7.064  -7.064 NaN
# Believer                                             -4.374  -4.374 NaN
# Blinding Lights                                      -5.934  -5.934 NaN
# Can't Hold Us - feat. Ray Dalton                     -4.457  -4.457 NaN
# Clean White Noise - Loopable with no fade           -28.460 -28.460 NaN
# Closer                                               -5.599  -5.599 NaN
# Dance Monkey                                         -6.400  -6.400 NaN
# Dancin (feat. Luvli) - Krono Remix                   -6.529  -6.529 NaN
# Do I Wanna Know?                                     -7.596  -7.596 NaN
# Falling                                              -8.756  -8.756 NaN
# Give Me Everything (feat. Ne-Yo, Afrojack & Nayer)   -3.206  -3.206 NaN
# Hey, Soul Sister                                     -4.440  -4.440 NaN
# I Fall Apart                                         -5.408  -5.408 NaN
# I'm Not The Only One                                 -5.795  -5.795 NaN
# Jocelyn Flores                                       -9.144  -9.144 NaN
# Just Give Me a Reason (feat. Nate Ruess)             -7.273  -7.273 NaN
# Just the Way You Are                                 -5.413  -5.413 NaN
# Locked out of Heaven                                 -4.165  -4.165 NaN
# Love The Way You Lie                                 -5.034  -5.034 NaN
# Lucid Dreams                                         -7.230  -7.230 NaN
# POWER                                                -4.746  -4.746 NaN
# Perfect                                              -6.312  -6.312 NaN
# Photograph                                          -10.480 -10.480 NaN
# Play Date                                            -5.077  -5.077 NaN
# Pumped Up Kicks                                      -5.849  -5.849 NaN
# ROCKSTAR (feat. Roddy Ricch)                         -7.956  -7.956 NaN
# SAD!                                                 -4.880  -4.880 NaN
# SICKO MODE                                           -3.714  -3.714 NaN
# Say So                                               -4.577  -4.577 NaN
# Say You Won't Let Go                                 -7.398  -7.398 NaN
# See You Again (feat. Charlie Puth)                   -7.503  -7.503 NaN
# Shape of You                                         -3.183  -3.183 NaN
# Starboy                                              -7.015  -7.015 NaN
# Stay With Me                                         -6.444  -6.444 NaN
# Story of My Life                                     -5.802  -5.802 NaN
# Stressed Out                                         -5.677  -5.677 NaN
# Supalonely                                           -4.689  -4.689 NaN
# Sweater Weather                                      -2.810  -2.810 NaN
# THE SCOTTS                                           -7.648  -7.648 NaN
# The Box                                              -6.687  -6.687 NaN
# The Less I Know The Better                           -4.083  -4.083 NaN
# Thinking out Loud                                    -6.061  -6.061 NaN
# TiK ToK                                              -2.718  -2.718 NaN
# Tongue Tied                                          -5.835  -5.835 NaN
# Toosie Slide                                         -9.750  -9.750 NaN
# Wait a Minute!                                       -5.279  -5.279 NaN
# Wake Me Up                                           -5.697  -5.697 NaN
# What Makes You Beautiful                             -2.494  -2.494 NaN
# When I Was Your Man                                  -8.648  -8.648 NaN
# Work Out                                             -6.903  -6.903 NaN
# death bed (coffee for your head) (feat. beabado...   -8.765  -8.765 NaN
# goosebumps                                           -3.370  -3.370 NaN
# ily (i love you baby) (feat. Emilee)                 -7.567  -7.567 NaN
# lovely (with Khalid)                                -10.109 -10.109 NaN
#
#                                                                       tempo  \
#                                                        min     max     mean
# name
# A Thousand Years                                    -7.445  -7.445  139.028
# All of Me                                           -7.064  -7.064  119.930
# Believer                                            -4.374  -4.374  124.949
# Blinding Lights                                     -5.934  -5.934  171.005
# Can't Hold Us - feat. Ray Dalton                    -4.457  -4.457  146.078
# Clean White Noise - Loopable with no fade          -28.460 -28.460    0.000
# Closer                                              -5.599  -5.599   95.010
# Dance Monkey                                        -6.400  -6.400   98.027
# Dancin (feat. Luvli) - Krono Remix                  -6.529  -6.529  119.896
# Do I Wanna Know?                                    -7.596  -7.596   85.030
# Falling                                             -8.756  -8.756  127.087
# Give Me Everything (feat. Ne-Yo, Afrojack & Nayer)  -3.206  -3.206  129.023
# Hey, Soul Sister                                    -4.440  -4.440   97.012
# I Fall Apart                                        -5.408  -5.408  143.950
# I'm Not The Only One                                -5.795  -5.795   82.001
# Jocelyn Flores                                      -9.144  -9.144  134.021
# Just Give Me a Reason (feat. Nate Ruess)            -7.273  -7.273   95.002
# Just the Way You Are                                -5.413  -5.413  109.012
# Locked out of Heaven                                -4.165  -4.165  143.994
# Love The Way You Lie                                -5.034  -5.034   86.989
# Lucid Dreams                                        -7.230  -7.230   83.903
# POWER                                               -4.746  -4.746  153.998
# Perfect                                             -6.312  -6.312   95.050
# Photograph                                         -10.480 -10.480  107.989
# Play Date                                           -5.077  -5.077  123.970
# Pumped Up Kicks                                     -5.849  -5.849  127.975
# ROCKSTAR (feat. Roddy Ricch)                        -7.956  -7.956   89.977
# SAD!                                                -4.880  -4.880   75.023
# SICKO MODE                                          -3.714  -3.714  155.008
# Say So                                              -4.577  -4.577  110.962
# Say You Won't Let Go                                -7.398  -7.398   85.043
# See You Again (feat. Charlie Puth)                  -7.503  -7.503   80.025
# Shape of You                                        -3.183  -3.183   95.977
# Starboy                                             -7.015  -7.015  186.003
# Stay With Me                                        -6.444  -6.444   84.094
# Story of My Life                                    -5.802  -5.802  121.070
# Stressed Out                                        -5.677  -5.677  169.977
# Supalonely                                          -4.689  -4.689  128.977
# Sweater Weather                                     -2.810  -2.810  124.053
# THE SCOTTS                                          -7.648  -7.648  129.979
# The Box                                             -6.687  -6.687  116.971
# The Less I Know The Better                          -4.083  -4.083  116.879
# Thinking out Loud                                   -6.061  -6.061   78.998
# TiK ToK                                             -2.718  -2.718  120.028
# Tongue Tied                                         -5.835  -5.835  112.960
# Toosie Slide                                        -9.750  -9.750   81.618
# Wait a Minute!                                      -5.279  -5.279  101.003
# Wake Me Up                                          -5.697  -5.697  124.080
# What Makes You Beautiful                            -2.494  -2.494  124.990
# When I Was Your Man                                 -8.648  -8.648   72.795
# Work Out                                            -6.903  -6.903   93.004
# death bed (coffee for your head) (feat. beabado...  -8.765  -8.765  144.026
# goosebumps                                          -3.370  -3.370  130.049
# ily (i love you baby) (feat. Emilee)                -7.567  -7.567  112.050
# lovely (with Khalid)                               -10.109 -10.109  115.284
#
#                                                                           \
#                                                      median std      min
# name
# A Thousand Years                                    139.028 NaN  139.028
# All of Me                                           119.930 NaN  119.930
# Believer                                            124.949 NaN  124.949
# Blinding Lights                                     171.005 NaN  171.005
# Can't Hold Us - feat. Ray Dalton                    146.078 NaN  146.078
# Clean White Noise - Loopable with no fade             0.000 NaN    0.000
# Closer                                               95.010 NaN   95.010
# Dance Monkey                                         98.027 NaN   98.027
# Dancin (feat. Luvli) - Krono Remix                  119.896 NaN  119.896
# Do I Wanna Know?                                     85.030 NaN   85.030
# Falling                                             127.087 NaN  127.087
# Give Me Everything (feat. Ne-Yo, Afrojack & Nayer)  129.023 NaN  129.023
# Hey, Soul Sister                                     97.012 NaN   97.012
# I Fall Apart                                        143.950 NaN  143.950
# I'm Not The Only One                                 82.001 NaN   82.001
# Jocelyn Flores                                      134.021 NaN  134.021
# Just Give Me a Reason (feat. Nate Ruess)             95.002 NaN   95.002
# Just the Way You Are                                109.012 NaN  109.012
# Locked out of Heaven                                143.994 NaN  143.994
# Love The Way You Lie                                 86.989 NaN   86.989
# Lucid Dreams                                         83.903 NaN   83.903
# POWER                                               153.998 NaN  153.998
# Perfect                                              95.050 NaN   95.050
# Photograph                                          107.989 NaN  107.989
# Play Date                                           123.970 NaN  123.970
# Pumped Up Kicks                                     127.975 NaN  127.975
# ROCKSTAR (feat. Roddy Ricch)                         89.977 NaN   89.977
# SAD!                                                 75.023 NaN   75.023
# SICKO MODE                                          155.008 NaN  155.008
# Say So                                              110.962 NaN  110.962
# Say You Won't Let Go                                 85.043 NaN   85.043
# See You Again (feat. Charlie Puth)                   80.025 NaN   80.025
# Shape of You                                         95.977 NaN   95.977
# Starboy                                             186.003 NaN  186.003
# Stay With Me                                         84.094 NaN   84.094
# Story of My Life                                    121.070 NaN  121.070
# Stressed Out                                        169.977 NaN  169.977
# Supalonely                                          128.977 NaN  128.977
# Sweater Weather                                     124.053 NaN  124.053
# THE SCOTTS                                          129.979 NaN  129.979
# The Box                                             116.971 NaN  116.971
# The Less I Know The Better                          116.879 NaN  116.879
# Thinking out Loud                                    78.998 NaN   78.998
# TiK ToK                                             120.028 NaN  120.028
# Tongue Tied                                         112.960 NaN  112.960
# Toosie Slide                                         81.618 NaN   81.618
# Wait a Minute!                                      101.003 NaN  101.003
# Wake Me Up                                          124.080 NaN  124.080
# What Makes You Beautiful                            124.990 NaN  124.990
# When I Was Your Man                                  72.795 NaN   72.795
# Work Out                                             93.004 NaN   93.004
# death bed (coffee for your head) (feat. beabado...  144.026 NaN  144.026
# goosebumps                                          130.049 NaN  130.049
# ily (i love you baby) (feat. Emilee)                112.050 NaN  112.050
# lovely (with Khalid)                                115.284 NaN  115.284
#
#
#                                                         max
# name
# A Thousand Years                                    139.028
# All of Me                                           119.930
# Believer                                            124.949
# Blinding Lights                                     171.005
# Can't Hold Us - feat. Ray Dalton                    146.078
# Clean White Noise - Loopable with no fade             0.000
# Closer                                               95.010
# Dance Monkey                                         98.027
# Dancin (feat. Luvli) - Krono Remix                  119.896
# Do I Wanna Know?                                     85.030
# Falling                                             127.087
# Give Me Everything (feat. Ne-Yo, Afrojack & Nayer)  129.023
# Hey, Soul Sister                                     97.012
# I Fall Apart                                        143.950
# I'm Not The Only One                                 82.001
# Jocelyn Flores                                      134.021
# Just Give Me a Reason (feat. Nate Ruess)             95.002
# Just the Way You Are                                109.012
# Locked out of Heaven                                143.994
# Love The Way You Lie                                 86.989
# Lucid Dreams                                         83.903
# POWER                                               153.998
# Perfect                                              95.050
# Photograph                                          107.989
# Play Date                                           123.970
# Pumped Up Kicks                                     127.975
# ROCKSTAR (feat. Roddy Ricch)                         89.977
# SAD!                                                 75.023
# SICKO MODE                                          155.008
# Say So                                              110.962
# Say You Won't Let Go                                 85.043
# See You Again (feat. Charlie Puth)                   80.025
# Shape of You                                         95.977
# Starboy                                             186.003
# Stay With Me                                         84.094
# Story of My Life                                    121.070
# Stressed Out                                        169.977
# Supalonely                                          128.977
# Sweater Weather                                     124.053
# THE SCOTTS                                          129.979
# The Box                                             116.971
# The Less I Know The Better                          116.879
# Thinking out Loud                                    78.998
# TiK ToK                                             120.028
# Tongue Tied                                         112.960
# Toosie Slide                                         81.618
# Wait a Minute!                                      101.003
# Wake Me Up                                          124.080
# What Makes You Beautiful                            124.990
# When I Was Your Man                                  72.795
# Work Out                                             93.004
# death bed (coffee for your head) (feat. beabado...  144.026
# goosebumps                                          130.049
# ily (i love you baby) (feat. Emilee)                112.050
# lovely (with Khalid)                                115.284
#
# [55 rows x 30 columns]

# %%
# danceablity

#create figure and axes
fig, ax = plt.subplots(figsize=(10,6))

# loop through each year and plot the danceability scores for the top 5 songs
for i, year in enumerate(top_songs.index.levels[0]):
    year_data = top_songs.loc[year]
    ax.scatter(year_data['name'], year_data['danceability'], label=year, marker='o')

   

# set the x-tick labels to be rotated 90 degrees
plt.xticks(rotation=90)

# set the x-axis and y-axis labels, and the title
plt.xlabel('Song')
plt.ylabel('Danceability')
plt.title('Top 5 Songs by Year')

# show the legend
ax.legend()

# display the plot
plt.show()

# %%
# acoustiness

#create figure and axes
fig, ax = plt.subplots(figsize=(10,6))

# loop through each year and plot the danceability scores for the top 5 songs
for i, year in enumerate(top_songs.index.levels[0]):
    year_data = top_songs.loc[year]
    ax.scatter(year_data['name'], year_data['acousticness'], label=year, marker='o' if i % 2 == 0 else 's')

# set the x-tick labels to be rotated 90 degrees
plt.xticks(rotation=90)

# set the x-axis and y-axis labels, and the title
plt.xlabel('Song')
plt.ylabel('Acousticness per Song')
plt.title('Songs Acousticness by year')

# show the legend
ax.legend()

# display the plot
plt.show()

# %%
# energy

#create figure and axes
fig, ax = plt.subplots(figsize=(10,6))

# loop through each year and plot the danceability scores for the top 5 songs
for i, year in enumerate(top_songs.index.levels[0]):
    year_data = top_songs.loc[year]
    ax.scatter(year_data['name'], year_data['energy'], label=year, marker='o' if i % 2 == 0 else 's')

# set the x-tick labels to be rotated 90 degrees
plt.xticks(rotation=90)

# set the x-axis and y-axis labels, and the title
plt.xlabel('Song')
plt.ylabel('Acousticness per Song')
plt.title('Songs energys by year')

# show the legend
ax.legend()

# display the plot
plt.show()

# %%
# liveness

#create figure and axes
fig, ax = plt.subplots(figsize=(10,6))

# loop through each year and plot the danceability scores for the top 5 songs
for i, year in enumerate(top_songs.index.levels[0]):
    year_data = top_songs.loc[year]
    ax.scatter(year_data['name'], year_data['liveness'], label=year, marker='o' if i % 2 == 0 else 's')

# set the x-tick labels to be rotated 90 degrees
plt.xticks(rotation=90)

# set the x-axis and y-axis labels, and the title
plt.xlabel('Song')
plt.ylabel('liveness per Song')
plt.title('Songs energys by year')

# show the legend
ax.legend()

# display the plot
plt.show()

# %%
# loudness

#create figure and axes
fig, ax = plt.subplots(figsize=(10,6))

# loop through each year and plot the danceability scores for the top 5 songs
for i, year in enumerate(top_songs.index.levels[0]):
    year_data = top_songs.loc[year]
    ax.scatter(year_data['name'], year_data['loudness'], label=year, marker='o' if i % 2 == 0 else 's')

# set the x-tick labels to be rotated 90 degrees
plt.xticks(rotation=90)

# set the x-axis and y-axis labels, and the title
plt.xlabel('Song')
plt.ylabel('loudness per Song')
plt.title('Songs energys by year')

# show the legend
ax.legend()

# display the plot
plt.show()

# %%
# tempo

#create figure and axes
fig, ax = plt.subplots(figsize=(10,6))

# loop through each year and plot the danceability scores for the top 5 songs
for i, year in enumerate(top_songs.index.levels[0]):
    year_data = top_songs.loc[year]
    ax.scatter(year_data['name'], year_data['tempo'], label=year, marker='o' if i % 2 == 0 else 's')

# set the x-tick labels to be rotated 90 degrees
plt.xticks(rotation=90)

# set the x-axis and y-axis labels, and the title
plt.xlabel('Song')
plt.ylabel('tempo per Song')
plt.title('Songs energys by year')

# show the legend
ax.legend()

# display the plot
plt.show()
